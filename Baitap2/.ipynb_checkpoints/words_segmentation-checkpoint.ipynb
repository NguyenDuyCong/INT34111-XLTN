# %%
import os
import pandas as pd
import re
import requests

# %%
# df = pd.read_excel('assignment1/Điểm danh Tran Quoc Long - INT3411 1 - Xu ly tieng noi.xlsx', sheet_name='assignment2-data')
# print(df.cell_value(0,0))

# %%
# from pyvi import ViTokenizer

# data = df['y-kien'][0]
# data = data.split("\n")
# data = data[1:]
# # data = "\n".join(data)
# n = len(data)
# i = 0
# list_file = []
# while i < n - 1:
#     list_file.append([data[i], data[i + 1]])
#     i += 2


# for i in range(len(list_file)):
#     list_file[i][1] = ViTokenizer.tokenize(list_file[i][1])

# print(list_file)

# %%
from pyvi import ViTokenizer
import xlrd

workbook = xlrd.open_workbook('assignment1/Điểm danh Tran Quoc Long - INT3411 1 - Xu ly tieng noi.xlsx')
worksheet = workbook.sheet_by_name('assignment2-data')

# %%
def get_text_from_cell(row, col):
    value = worksheet.cell_value(row, col)
#     print(value)
    if value is None:
        return ""
    value = value.split('\n')
    
    data = ""
    for i in range(2, len(value)):
        if i % 2 == 0 and value[i] is not None:
            data += value[i] + "\n"
    
    return data

# %%
value = ""
for i in range(1, 38):
    for j in range(3, 18):
        value += get_text_from_cell(i, j)
        
value = ViTokenizer.tokenize(value)
value = value.lower()
print (value)
# Out:
# ' dùng khách_sạn làm nơi ở cho nhân_viên y_tế chống dịch ' . nhân_viên y_tế là vốn quý_giá nhất trong cuộc_chiến chống covid - 19 nên chúng_ta cần trân_trọng và bảo_vệ họ . các nhân_viên y_tế tham_gia phòng_chống dịch covid - 19 là những người tiếp_xúc trực_tiếp với một_số đông người nhiễm và nghi nhiễm ncov , nên họ là f1 theo phân_loại đối_tượng nghi nhiễm . từ những gì đã trải qua tại các nước khác trên thế_giới như trung_quốc , ấn_độ ... chúng_ta cần lên kế_hoạch bảo_đảm một chỗ nghỉ_ngơi an_toàn , tiện_nghi cho các nhân_viên y_tế tham_gia chống dịch . các nhân_viên y_tế anh_dũng chống dịch ở tuyến đầu , nhưng chính họ lại không dám về nhà với vợ_chồng , con_cái khi được nghỉ_ngơi vì sợ lây_nhiễm cho gia_đình như các trường_hợp ở trung_quốc . họ cũng bị hàng_xóm xua_đuổi , thậm_chí đánh_đuổi như ở ấn_độ . vì_vậy , chúng_ta cần khẩn_trương lên kế_hoạch bố_trí chỗ nghỉ_ngơi riêng_biệt giống như các khu cách_ly dành cho nhân_viên y_tế . tốt nhất_là lựa_chọn các khách_sạn gần bệnh_viện nơi họ làm_việc . ngoài_ra , chúng_ta cũng cần có sự điều_động các nhân_viên y_tế từ các tỉnh khác về trợ_giúp các tỉnh đang có nhiều ca mắc bệnh , nên cũng phải bố_trí chỗ ăn_ở cho họ . khách_sạn cũng là lựa_chọn tốt nhất vì tiện_nghi và hạn_chế tối_đa lây_nhiễm chéo . nhân_viên y_tế là vốn quý_giá nhất trong cuộc_chiến chống covid - 19 nên chúng_ta cần trân_trọng và bảo_vệ họ . các công_việc mà người khác có_thể làm sau một khóa học nhanh như đo nhiệt_độ , phun sát_trùng diệt khuẩn hay thậm_chí lấy mẫu dịch thể , chúng_ta có_thể hướng_dẫn các sinh_viên ngành y để cùng tham_gia chống dịch , giảm tải bớt áp_lực cho các y bác_sĩ . việc thiếu_thốn vật_tư y_tế và đề_phòng lây_nhiễm chéo , tôi cho rằng nhân_viên y_tế chỉ mặc đồ bảo_hộ và tiếp_xúc gần không an_toàn bằng cách cách_ly hẳn họ và người cần kiểm_tra bằng một vách ngăn trong suốt . trên vách ngăn đó có_thể gắn các cánh_tay nilon hoặc cao_su để nhân_viên y_tế thò tay vào thao_tác các dụng_cụ y_tế như đo nhiệt_độ , lấy mẫu . hãy trợ_giúp các chiến_sĩ trên mặt_trận chống covid - 19 bằng cách nghe theo khuyến_cáo của họ ; cung_cấp cho họ điều_kiện làm_việc , sinh_hoạt tốt nhất ; chăm_sóc gia_đình họ nếu cần để họ yên_tâm làm_việc . iphone 5g sẽ vẫn ra_mắt đúng hẹn apple được cho là sẽ ra_mắt iphone mới có 5g vào tháng 9 tới , nhưng iphone thế_hệ tiếp_theo có_thể bị trì_hoãn " hon hai ( foxconn ) , đối_tác lắp_ráp của apple , đang quay lại tập_trung sản_xuất iphone với công_suất gần như bình_thường việc sản_xuất hàng_loạt iphone mới sẽ không diễn ra cho đến mùa hè do đó , iphone thế_hệ tiếp_theo với mạng 5g vẫn được lên kế_hoạch ra_mắt vào mùa thu " , bloomberg trích_dẫn nguồn tin thân_cận theo nguồn tin , nhà_máy của foxconn ở trịnh_châu đã bị buộc hoãn một_số công_đoạn sản_xuất do vẫn thực_hiện các biện_pháp kiểm_dịch nghiêm_ngặt mà chính_quyền địa_phương đưa ra tuy_vậy , công_ty đã dùng chiến_lược thu_hút nhân_công_bằng lương , thưởng , do đó vẫn đảm_bảo công_suất lắp_ráp khi quay lại hoạt_động tuy_nhiên , nguồn tin nhấn_mạnh , những smartphone ra_mắt sau iphone 5g sẽ bị trì_hoãn , thậm_chí ra muộn hơn thay_vì tháng 9 hàng năm , do sự gián_đoạn mạng_lưới chuỗi cung_ứng rộng hơn của apple thực_tế , foxconn chỉ là một phần trong đối_tác của apple , còn chuỗi cung_ứng của công_ty mỹ rộng khắp trên thế_giới trước đó , một_số báo_cáo cho rằng iphone mới có_thể ra_mắt không đúng lịch_trình tháng 9 hàng năm theo nikkei , các giám_đốc cấp cao của apple đang lo_lắng iphone thế_hệ tiếp_theo sẽ có nhu_cầu " thấp bất_thường " do covid - 19 ngay cả khi đối_tác của công_ty mỹ tăng_tốc sản_xuất và đảm_bảo số_lượng như mọi năm , người tiêu_dùng cũng sẽ ít chi tiền hơn cho điện_thoại mới nhằm tập_trung cho các mặt_hàng thiết_yếu còn theo reuters , iphone 2020 vẫn ra_mắt vào tháng 9 nhưng bán ra muộn hơn do chuỗi cung_ứng cho foxconn không đảm_bảo tiến_độ sản_xuất hàng_loạt apple dự_kiến phát_hành bốn mẫu iphone 12 vào tháng 9 năm nay , gồm một mẫu 5,4 inch , hai mẫu 6,1 inch và một mẫu 6,7 inch tất_cả được t ...

# %%
count_words = {}
words = value.split(' ')
# print(words)

# %%
from string import punctuation
stop_word = []
with open("./vietnamese-stopwords-dash.txt",encoding="utf-8") as f :
    text = f.read()
    for word in text.split() :
        stop_word.append(word)
    f.close()
    punc = list(punctuation)
stop_word = stop_word + punc
print(stop_word)
# Out:
# ['a_lô', 'a_ha', 'ai', 'ai_ai', 'ai_nấy', 'ai_đó', 'alô', 'amen', 'anh', 'anh_ấy', 'ba', 'ba_ba', 'ba_bản', 'ba_cùng', 'ba_họ', 'ba_ngày', 'ba_ngôi', 'ba_tăng', 'bao_giờ', 'bao_lâu', 'bao_nhiêu', 'bao_nả', 'bay_biến', 'biết', 'biết_bao', 'biết_bao_nhiêu', 'biết_chắc', 'biết_chừng_nào', 'biết_mình', 'biết_mấy', 'biết_thế', 'biết_trước', 'biết_việc', 'biết_đâu', 'biết_đâu_chừng', 'biết_đâu_đấy', 'biết_được', 'buổi', 'buổi_làm', 'buổi_mới', 'buổi_ngày', 'buổi_sớm', 'bà', 'bà_ấy', 'bài', 'bài_bác', 'bài_bỏ', 'bài_cái', 'bác', 'bán', 'bán_cấp', 'bán_dạ', 'bán_thế', 'bây_bẩy', 'bây_chừ', 'bây_giờ', 'bây_nhiêu', 'bèn', 'béng', 'bên', 'bên_bị', 'bên_có', 'bên_cạnh', 'bông', 'bước', 'bước_khỏi', 'bước_tới', 'bước_đi', 'bạn', 'bản', 'bản_bộ', 'bản_riêng', 'bản_thân', 'bản_ý', 'bất_chợt', 'bất_cứ', 'bất_giác', 'bất_kì', 'bất_kể', 'bất_kỳ', 'bất_luận', 'bất_ngờ', 'bất_nhược', 'bất_quá', 'bất_quá_chỉ', 'bất_thình_lình', 'bất_tử', 'bất_đồ', 'bấy', 'bấy_chầy', 'bấy_chừ', 'bấy_giờ', 'bấy_lâu', 'bấy_lâu_nay', 'bấy_nay', 'bấy_nhiêu', 'bập_bà_bập_bõm', 'bập_bõm', 'bắt_đầu', 'bắt_đầu_từ', 'bằng', 'bằng_cứ', 'bằng_không', 'bằng_người', 'bằng_nhau', 'bằng_như', 'bằng_nào', 'bằng_nấy', 'bằng_vào', 'bằng_được', 'bằng_ấy', 'bển', 'bệt', 'bị', 'bị_chú', 'bị_vì', 'bỏ', 'bỏ_bà', 'bỏ_cha', 'bỏ_cuộc', 'bỏ_không', 'bỏ_lại', 'bỏ_mình', 'bỏ_mất', 'bỏ_mẹ', 'bỏ_nhỏ', 'bỏ_quá', 'bỏ_ra', 'bỏ_riêng', 'bỏ_việc', 'bỏ_xa', 'bỗng', 'bỗng_chốc', 'bỗng_dưng', 'bỗng_không', 'bỗng_nhiên', 'bỗng_nhưng', 'bỗng_thấy', 'bỗng_đâu', 'bộ', 'bộ_thuộc', 'bộ_điều', 'bội_phần', 'bớ', 'bởi', 'bởi_ai', 'bởi_chưng', 'bởi_nhưng', 'bởi_sao', 'bởi_thế', 'bởi_thế_cho_nên', 'bởi_tại', 'bởi_vì', 'bởi_vậy', 'bởi_đâu', 'bức', 'cao', 'cao_lâu', 'cao_ráo', 'cao_răng', 'cao_sang', 'cao_số', 'cao_thấp', 'cao_thế', 'cao_xa', 'cha', 'cha_chả', 'chao_ôi', 'chia_sẻ', 'chiếc', 'cho', 'cho_biết', 'cho_chắc', 'cho_hay', 'cho_nhau', 'cho_nên', 'cho_rằng', 'cho_rồi', 'cho_thấy', 'cho_tin', 'cho_tới', 'cho_tới_khi', 'cho_về', 'cho_ăn', 'cho_đang', 'cho_được', 'cho_đến', 'cho_đến_khi', 'cho_đến_nỗi', 'choa', 'chu_cha', 'chui_cha', 'chung', 'chung_cho', 'chung_chung', 'chung_cuộc', 'chung_cục', 'chung_nhau', 'chung_qui', 'chung_quy', 'chung_quy_lại', 'chung_ái', 'chuyển', 'chuyển_tự', 'chuyển_đạt', 'chuyện', 'chuẩn_bị', 'chành_chạnh', 'chí_chết', 'chính', 'chính_bản', 'chính_giữa', 'chính_là', 'chính_thị', 'chính_điểm', 'chùn_chùn', 'chùn_chũn', 'chú', 'chú_dẫn', 'chú_khách', 'chú_mày', 'chú_mình', 'chúng', 'chúng_mình', 'chúng_ta', 'chúng_tôi', 'chúng_ông', 'chăn_chắn', 'chăng', 'chăng_chắc', 'chăng_nữa', 'chơi', 'chơi_họ', 'chưa', 'chưa_bao_giờ', 'chưa_chắc', 'chưa_có', 'chưa_cần', 'chưa_dùng', 'chưa_dễ', 'chưa_kể', 'chưa_tính', 'chưa_từng', 'chầm_chập', 'chậc', 'chắc', 'chắc_chắn', 'chắc_dạ', 'chắc_hẳn', 'chắc_lòng', 'chắc_người', 'chắc_vào', 'chắc_ăn', 'chẳng_lẽ', 'chẳng_những', 'chẳng_nữa', 'chẳng_phải', 'chết_nỗi', 'chết_thật', 'chết_tiệt', 'chỉ', 'chỉ_chính', 'chỉ_có', 'chỉ_là', 'chỉ_tên', 'chỉn', 'chị', 'chị_bộ', 'chị_ấy', 'chịu', 'chịu_chưa', 'chịu_lời', 'chịu_tốt', 'chịu_ăn', 'chọn', 'chọn_bên', 'chọn_ra', 'chốc_chốc', 'chớ', 'chớ_chi', 'chớ_gì', 'chớ_không', 'chớ_kể', 'chớ_như', 'chợt', 'chợt_nghe', 'chợt_nhìn', 'chủn', 'chứ', 'chứ_ai', 'chứ_còn', 'chứ_gì', 'chứ_không', 'chứ_không_phải', 'chứ_lại', 'chứ_lị', 'chứ_như', 'chứ_sao', 'coi_bộ', 'coi_mòi', 'con', 'con_con', 'con_dạ', 'con_nhà', 'con_tính', 'cu_cậu', 'cuối', 'cuối_cùng', 'cuối_điểm', 'cuốn', 'cuộc', 'càng', 'càng_càng', 'càng_hay', 'cá_nhân', 'các', 'các_cậu', 'cách', 'cách_bức', 'cách_không', 'cách_nhau', 'cách_đều', 'cái', 'cái_gì', 'cái_họ', 'cái_đã', 'cái_đó', 'cái_ấy', 'câu_hỏi', 'cây', 'cây_nước', 'còn', 'còn_như', 'còn_nữa', 'còn_thời_gian', 'còn_về', 'có', 'có_ai', 'có_chuyện', 'có_chăng', 'có_chăng_là', 'có_chứ', 'có_cơ', 'có_dễ', 'có_họ', 'có_khi', 'có_ngày', 'có_người', 'có_nhiều', 'có_nhà', 'có_phải', 'có_số', 'có_tháng', 'có_thế', 'có_thể', 'có_vẻ', 'có_ý', 'có_ăn', 'có_điều', 'có_điều_kiện', 'có_đáng', 'có_đâu', 'có_được', ' ...

# %%
list_words = []
for word in words:
    if (word not in stop_word) :
        if ("_" in word) or (word.isalpha() == True):
            list_words.append(word)

print(list_words)
# Out:
# ['khách_sạn', 'nhân_viên', 'y_tế', 'chống', 'dịch', 'nhân_viên', 'y_tế', 'vốn', 'quý_giá', 'cuộc_chiến', 'chống', 'covid', 'trân_trọng', 'bảo_vệ', 'nhân_viên', 'y_tế', 'tham_gia', 'phòng_chống', 'dịch', 'covid', 'tiếp_xúc', 'đông', 'nhiễm', 'nghi', 'nhiễm', 'ncov', 'phân_loại', 'đối_tượng', 'nghi', 'nhiễm', 'trải', 'thế_giới', 'trung_quốc', 'ấn_độ', 'kế_hoạch', 'bảo_đảm', 'chỗ', 'nghỉ_ngơi', 'an_toàn', 'tiện_nghi', 'nhân_viên', 'y_tế', 'tham_gia', 'chống', 'dịch', 'nhân_viên', 'y_tế', 'anh_dũng', 'chống', 'dịch', 'tuyến', 'đầu', 'dám', 'vợ_chồng', 'con_cái', 'nghỉ_ngơi', 'sợ', 'lây_nhiễm', 'gia_đình', 'trường_hợp', 'trung_quốc', 'hàng_xóm', 'xua_đuổi', 'đánh_đuổi', 'ấn_độ', 'khẩn_trương', 'kế_hoạch', 'bố_trí', 'chỗ', 'nghỉ_ngơi', 'riêng_biệt', 'khu', 'cách_ly', 'nhân_viên', 'y_tế', 'lựa_chọn', 'khách_sạn', 'bệnh_viện', 'làm_việc', 'điều_động', 'nhân_viên', 'y_tế', 'tỉnh', 'trợ_giúp', 'tỉnh', 'ca', 'mắc', 'bệnh', 'bố_trí', 'chỗ', 'ăn_ở', 'khách_sạn', 'lựa_chọn', 'tiện_nghi', 'hạn_chế', 'tối_đa', 'lây_nhiễm', 'chéo', 'nhân_viên', 'y_tế', 'vốn', 'quý_giá', 'cuộc_chiến', 'chống', 'covid', 'trân_trọng', 'bảo_vệ', 'công_việc', 'khóa', 'học', 'đo', 'nhiệt_độ', 'phun', 'sát_trùng', 'diệt', 'khuẩn', 'mẫu', 'dịch', 'thể', 'hướng_dẫn', 'sinh_viên', 'ngành', 'y', 'tham_gia', 'chống', 'dịch', 'tải', 'bớt', 'áp_lực', 'y', 'bác_sĩ', 'thiếu_thốn', 'vật_tư', 'y_tế', 'đề_phòng', 'lây_nhiễm', 'chéo', 'nhân_viên', 'y_tế', 'mặc', 'đồ', 'bảo_hộ', 'tiếp_xúc', 'an_toàn', 'cách_ly', 'hẳn', 'kiểm_tra', 'vách', 'ngăn', 'suốt', 'vách', 'ngăn', 'gắn', 'cánh_tay', 'nilon', 'cao_su', 'nhân_viên', 'y_tế', 'thò', 'thao_tác', 'dụng_cụ', 'y_tế', 'đo', 'nhiệt_độ', 'mẫu', 'trợ_giúp', 'chiến_sĩ', 'mặt_trận', 'chống', 'covid', 'khuyến_cáo', 'cung_cấp', 'làm_việc', 'sinh_hoạt', 'chăm_sóc', 'gia_đình', 'yên_tâm', 'làm_việc', 'iphone', 'ra_mắt', 'hẹn', 'apple', 'ra_mắt', 'iphone', 'iphone', 'thế_hệ', 'trì_hoãn', 'hon', 'hai', 'foxconn', 'đối_tác', 'lắp_ráp', 'apple', 'sản_xuất', 'iphone', 'công_suất', 'bình_thường', 'sản_xuất', 'hàng_loạt', 'iphone', 'diễn', 'mùa', 'hè', 'iphone', 'thế_hệ', 'mạng', 'kế_hoạch', 'ra_mắt', 'mùa', 'thu', 'bloomberg', 'trích_dẫn', 'thân_cận', 'nhà_máy', 'foxconn', 'trịnh_châu', 'buộc', 'hoãn', 'công_đoạn', 'sản_xuất', 'biện_pháp', 'kiểm_dịch', 'nghiêm_ngặt', 'chính_quyền', 'địa_phương', 'công_ty', 'chiến_lược', 'thu_hút', 'nhân_công_bằng', 'lương', 'thưởng', 'công_suất', 'lắp_ráp', 'hoạt_động', 'nhấn_mạnh', 'smartphone', 'ra_mắt', 'iphone', 'trì_hoãn', 'muộn', 'thay_vì', 'hàng', 'gián_đoạn', 'mạng_lưới', 'chuỗi', 'cung_ứng', 'rộng', 'apple', 'foxconn', 'đối_tác', 'apple', 'chuỗi', 'cung_ứng', 'công_ty', 'mỹ', 'rộng', 'khắp', 'thế_giới', 'báo_cáo', 'iphone', 'ra_mắt', 'lịch_trình', 'hàng', 'nikkei', 'giám_đốc', 'apple', 'lo_lắng', 'iphone', 'thế_hệ', 'nhu_cầu', 'bất_thường', 'covid', 'đối_tác', 'công_ty', 'mỹ', 'tăng_tốc', 'sản_xuất', 'số_lượng', 'tiêu_dùng', 'chi', 'tiền', 'điện_thoại', 'mặt_hàng', 'thiết_yếu', 'reuters', 'iphone', 'ra_mắt', 'muộn', 'chuỗi', 'cung_ứng', 'foxconn', 'tiến_độ', 'sản_xuất', 'hàng_loạt', 'apple', 'dự_kiến', 'phát_hành', 'bốn', 'mẫu', 'iphone', 'mẫu', 'inch', 'hai', 'mẫu', 'inch', 'mẫu', 'inch', 'trang_bị', 'màn_hình', 'oled', 'thiết_kế', 'vuông', 'iphone', 'iphone', 'mạng_di_động', 'tốc_độ', 'kỳ_vọng', 'đòn_bẩy', 'iphone', 'bối_cảnh', 'doanh_số', 'smartphone', 'dấu_hiệu', 'đi', 'chuyên_gia', 'apple', 'iphone', 'ming', 'chi', 'kuo', 'phân_tích', 'dự_đoán', 'iphone', 'apple', 'mẫu', 'smartphone', 'cổng', 'kết_nối', 'thiết_bị', 'trải', 'nghiệm', 'dây', 'đề_cập', 'chi_tiết', 'kiếm', 'hạnh_phúc', 'mẹ', 'đơn_thân', 'mẹ', 'đơn_thân', 'chồng', 'cũ', 'chơi_bời', 'dính', 'tệ_nạn', 'xã_hội', 'đối_xử', 'tệ_bạc', 'yêu', 'gặp_gỡ', 'đi', 'chồng', 'rơi', 'chuỗi', 'nước_mắt', 'cuộc_sống', 'địa_ngục', 'hai', 'chồng', 'yêu', 'say_đắm', 'hạnh_phúc', 'suốt', 'hai', 'trai', 'vợ', 'lo_lắng', 'chăm_sóc', 'suốt', 'cảm_nhận', 'hạnh_phúc', 'tình_yêu', 'yêu', 'gặp_mặt', 'gia_đình', 'ngỏ', 'hoàn_cảnh', 'dám', 'hy_vọng', 'ngỏ', 'chẳng', 'câ ...

# %%
for word in list_words:
    if count_words.get(word) is None:
        count_words[word] = 1
    else:
        count_words[word] += 1

# print (count_words)

# %%
list_term = count_words
list_term = sorted(list_term.items(), key=lambda x:x[1], reverse=True)

# %%
# print(list_term)

# %%
for i in range(0, 100):
    print(list_term[i])
# Out:
# ('covid', 630)
# ('đi', 466)
# ('hai', 422)
# ('y_tế', 400)
# ('xe', 371)
# ('dịch', 344)
# ('bệnh_nhân', 311)
# ('cách_ly', 308)
# ('ncov', 290)
# ('ca', 288)
# ('bệnh_viện', 280)
# ('việt_nam', 278)
# ('nhiễm', 261)
# ('hàng', 244)
# ('dân', 229)
# ('nhân_viên', 221)
# ('mỹ', 216)
# ('học', 210)
# ('hà_nội', 210)
# ('đồng', 210)
# ('wav', 210)
# ('hoạt_động', 208)
# ('triệu', 207)
# ('đầu', 203)
# ('dịch_bệnh', 195)
# ('thành_phố', 184)
# ('đường', 184)
# ('tổ_chức', 181)
# ('tuần', 179)
# ('bác_sĩ', 178)
# ('gia_đình', 175)
# ('làm_việc', 170)
# ('bệnh', 168)
# ('tiền', 167)
# ('chống', 163)
# ('virus', 162)
# ('xã_hội', 155)
# ('tp', 155)
# ('trường_hợp', 151)
# ('công_ty', 151)
# ('phòng', 149)
# ('quốc_gia', 148)
# ('thế_giới', 147)
# ('tỉnh', 147)
# ('sống', 146)
# ('xét_nghiệm', 146)
# ('giúp', 140)
# ('trẻ', 139)
# ('mẫu', 137)
# ('mùa', 137)
# ('hôm', 137)
# ('chính_phủ', 135)
# ('giá', 135)
# ('rác', 135)
# ('học_sinh', 134)
# ('điều_trị', 130)
# ('sản_xuất', 129)
# ('nghiên_cứu', 127)
# ('hãng', 125)
# ('hcm', 124)
# ('quyết_định', 122)
# ('thông_tin', 120)
# ('lây_nhiễm', 119)
# ('đội', 119)
# ('an_toàn', 117)
# ('trung_quốc', 116)
# ('ảnh_hưởng', 116)
# ('trực_tuyến', 115)
# ('sức_khỏe', 113)
# ('dịch_vụ', 113)
# ('ghi_nhận', 113)
# ('ảnh', 113)
# ('đại_học', 112)
# ('khẩu_trang', 112)
# ('cơ_sở', 111)
# ('nghỉ', 111)
# ('cộng_đồng', 111)
# ('thị_trường', 110)
# ('địa_phương', 107)
# ('hệ_thống', 106)
# ('dừng', 105)
# ('hiện', 105)
# ('biện_pháp', 103)
# ('công_nghệ', 103)
# ('tham_gia', 102)
# ('phim', 101)
# ('kết_quả', 100)
# ('mạng', 99)
# ('lao_động', 98)
# ('giải', 98)
# ('đóng_cửa', 97)
# ('đông', 96)
# ('hạn_chế', 94)
# ('khả_năng', 94)
# ('mua', 92)
# ('bảo_vệ', 91)
# ('ngành', 91)
# ('đứng', 91)
# ('gửi', 91)
# ('nội_dung', 91)

# %%
selected_words = ['hai', 'đường', 'tiền', 'y_tế', 'bệnh_nhân']

# %%
def header_col(col):
    return worksheet.cell_value(0, col)

def get_mssv(row):
    return str(worksheet.cell_value(row, 1))[:-2] + '_' + worksheet.cell_value(row, 2)

# %%
def find_words_in_file(word):
    list_file = []
    for i in range(1, 38):
        for j in range(3, 18):
            data = worksheet.cell_value(i,j)
            data = data.lower()
            data = data.split('\n')
            for d in data:
                if word in d:
                    path = data[data.index(d) - 1] + ' | '
                    path += header_col(j) + ' | '
                    path += str(get_mssv(i))
                    list_file.append(path)
    return list_file

# %%
test = find_words_in_file('hai')
print("tổng có {0} file".format(len(test)))

list_id = {}
for t in test:
    t = t.split("|")[2].strip()
#     t = t.split("_")[0].strip()
    if list_id.get(t) is None:
        list_id[t] = 1
    else:
        list_id[t] += 1

list_id = sorted(list_id.items(), key=lambda x:x[1], reverse=True)
for k, v in list_id:
    print(k, " : ", v)

find_file = "17021182_Nguyễn Duy Công"
for t in test:
    s = t.split("|")[2].strip()
    if s == find_file:
        print(t)
# Out:
# tổng có 601 file
# 17021194_Nguyễn Khả Quang Huy  :  43
# 17021183_Hồ Đức Đạt  :  38
# 17021203_Trần Văn Quân  :  35
# 17020019_Lê Mai An  :  33
# 17021200_Trần Phương Nam  :  32
# 17021180_Phạm Lê Việt Anh  :  31
# 17021182_Nguyễn Duy Công  :  31
# 17020709_Dương Thu Hà  :  27
# 17021187_Phạm Minh Đức  :  26
# 17020646_Đỗ Đường Duy  :  26
# 17021089_Trần Đức Trung  :  20
# 17021186_Nguyễn Thị Phương Đông  :  19
# 17020028_Đỗ Hoàng Khánh  :  19
# 17021195_Nguyễn Văn Linh  :  19
# 17021201_Nguyễn Trọng Nghĩa  :  19
# 17020970_Nguyễn Văn Phương  :  19
# 17021185_Nguyễn Tiến Đạt  :  18
# 17021192_Nguyễn Đức Hùng  :  16
# 17021197_Vương Bảo Long  :  15
# 17020103_Nguyễn Hùng Quang  :  15
# 17021059_Đặng Hữu Tiến  :  15
# 17021311_Cao Minh Nhật  :  15
# 16021398_Đinh Khánh Linh  :  14
# 17020035_Nguyễn Nhật Minh  :  14
# 17021184_Nguyễn Thành Đạt  :  12
# 17021191_Nguyễn Huy Hoàng  :  10
# 16022494_Nguyễn Chiến Thắng  :  10
# 17021019_Phạm Sơn Thành  :  10
# out1.wav | so-hoa | 17021182_Nguyễn Duy Công
# out6.wav | tam-su | 17021182_Nguyễn Duy Công
# out8.wav | xe | 17021182_Nguyễn Duy Công
# out14.wav | xe | 17021182_Nguyễn Duy Công
# out13.wav | khoa-hoc | 17021182_Nguyễn Duy Công
# out5.wav | du-lich | 17021182_Nguyễn Duy Công
# out2.wav | doi-song | 17021182_Nguyễn Duy Công
# out10.wav | doi-song | 17021182_Nguyễn Duy Công
# out17.wav | doi-song | 17021182_Nguyễn Duy Công
# out23.wav | doi-song | 17021182_Nguyễn Duy Công
# out33.wav | doi-song | 17021182_Nguyễn Duy Công
# out34.wav | doi-song | 17021182_Nguyễn Duy Công
# out45.wav | doi-song | 17021182_Nguyễn Duy Công
# out59.wav | doi-song | 17021182_Nguyễn Duy Công
# out69.wav | doi-song | 17021182_Nguyễn Duy Công
# out73.wav | doi-song | 17021182_Nguyễn Duy Công
# out76.wav | doi-song | 17021182_Nguyễn Duy Công
# out88.wav | doi-song | 17021182_Nguyễn Duy Công
#  | suc-khoe | 17021182_Nguyễn Duy Công
# out3.wav | suc-khoe | 17021182_Nguyễn Duy Công
# out5.wav | suc-khoe | 17021182_Nguyễn Duy Công
#  | giao-duc | 17021182_Nguyễn Duy Công
# out26.wav | giao-duc | 17021182_Nguyễn Duy Công
#  | phap-luat | 17021182_Nguyễn Duy Công
# out0.wav | phap-luat | 17021182_Nguyễn Duy Công
# out3.wav | phap-luat | 17021182_Nguyễn Duy Công
# out20.wav | the-thao | 17021182_Nguyễn Duy Công
# out28.wav | the-thao | 17021182_Nguyễn Duy Công
# out4.wav | giai-tri | 17021182_Nguyễn Duy Công
# out10.wav | giai-tri | 17021182_Nguyễn Duy Công
# out22.wav | giai-tri | 17021182_Nguyễn Duy Công
